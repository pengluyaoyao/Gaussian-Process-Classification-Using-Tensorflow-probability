# %%
#import tensorflow.compat.v1 as tf

import tensorflow.compat.v2 as tf
import tensorflow_probability as tfp

#tf.compat.v1.enable_eager_execution()


#tf.disable_v2_behavior()
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import nngp2
import itertools
import gpr
#import ard
import sys
from sklearn.metrics import f1_score
    
tfb = tfp.bijectors
tfd = tfp.distributions
tfk = tfp.math.psd_kernels
# %pylab inline
tf.__version__
tf.enable_v2_behavior()
tf.executing_eagerly()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Populating the interactive namespace from numpy and matplotlib
# True

# %%
### Top50 with full wide features

# train = pd.read_csv('data/mimic/train.csv')
# dev = pd.read_csv('data/mimic/dev.csv')
# test = pd.read_csv('data/mimic/test.csv')

# print(train.shape, dev.shape, test.shape)

# %%
###Top10

from read_mimic_text import getSplitSentences, read_sentence

train = pd.read_csv('/home/ubuntu/S3/mimic/train_dev_top10_normal_text.csv')
#dev = pd.read_csv('/home/ubuntu/S3/mimic/dev_top10.csv')
#train = pd.concat([train, dev])
test = pd.read_csv('/home/ubuntu/S3/mimic/test_top10_normal_text.csv')

X_d_train = np.load('/home/ubuntu/S3/mimic/embs_top10_normal_text_tr.npy')
#X_d_dev = np.load('/home/ubuntu/S3/mimic/embs_top10_de.npy')
#X_d_train = np.concatenate([X_d_train, X_d_dev], axis=0)
X_d_test = np.load('/home/ubuntu/S3/mimic/embs_top10_normal_text_te.npy')
    
# list_of_lists_of_words_tr = getSplitSentences(train['TEXT'].tolist())
# #list_of_lists_of_words_de = getSplitSentences(dev['TEXT'].tolist())
# list_of_lists_of_words_te = getSplitSentences(test['TEXT'].tolist())

# maxlen_train, clean_sentences_train = read_sentence(list_of_lists_of_words_tr)
# #maxlen_dev, clean_sentences_dev = read_sentence(list_of_lists_of_words_de)
# maxlen_test, clean_sentences_test = read_sentence(list_of_lists_of_words_te)

# sentences_train = [" ".join(sent)for sent in clean_sentences_train] #join words together sentence by sentence
# #sentences_dev = [" ".join(sent) for sent in clean_sentences_dev]
# sentences_test = [" ".join(sent) for sent in clean_sentences_test]

# #COMPUTE TFIDF
# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# vectorizer = TfidfVectorizer(ngram_range =(1,1))
# tfidf = vectorizer.fit_transform(sentences_train+sentences_test)
# X_w_train = tfidf[0:len(sentences_train), :].todense()##(9634, 73242)
# X_w_test = tfidf[len(sentences_train):, :]# (2207, 73242)
# # K_w_data_data = X_w_train.dot(X_w_train.T)
# # K_w_data_test = X_w_train.dot(X_w_dev.T)
# #print(K_w_data_data.shape, K_w_data_test.shape)

# #COMPUTE PCA
# from sklearn.decomposition import PCA

# pca = PCA(n_components=600)
# X_w_pca_train = pca.fit_transform(X_w_train)
# X_w_test_pca = pca.transform(X_w_test)
# X_w_train=tfidf_train.todense()
# X_w_dev=tfidf_dev.todense()

# X_w_test_pca = pca.transform(X_w_test)

# x_w_train_pca = np.concatenate([X_w_train_pca[is_positive][msk1], X_w_train_pca[~is_positive][msk0]], axis=0)
#x_w_dev_pca = pca.transform(X_w_dev)

# k_w_data_data = x_w_train_pca.dot(x_w_train_pca.T)
# k_w_data_test = x_w_train_pca.dot(x_w_dev_pca.T)

# print(np.sum(pca.explained_variance_ratio_))

# print(k_w_data_data.shape, k_w_data_test.shape, k_w_test_test.shape)

# %%
### REMOVE LONG TEXTS AND GENERATE USE

# #train['TEXT'].str.len(), 
# train['TEXT_lengths'] = train['TEXT'].apply(lambda x: len(x.split()))
# #train_sorted_by_lengths = train.sort_values(by=['TEXT_lengths'], ascending=False)
# train_normal_text=train[train['TEXT_lengths']<780]
# test['TEXT_lengths'] = test['TEXT'].apply(lambda x: len(x.split()))
# #train_sorted_by_lengths = train.sort_values(by=['TEXT_lengths'], ascending=False)
# test_normal_text=test[test['TEXT_lengths']<780]
# print(train_normal_text.shape, test_normal_text.shape)

# import tensorflow_hub as hub
# texts = test_normal_text['TEXT'].tolist()

# with hub.eval_function_for_module("https://tfhub.dev/google/universal-sentence-encoder-large/3") as f:
    
#     for i in tqdm(range(len(texts)//100+1)):
        
#         try:
#             texts_batch = texts[i*100:(i+1)*100]
#         except IndexError:
#             texts_batch= texts[i*100:]
        
#         embs_batch=f(texts_batch)
        
#         if i==0:
#             embs_ = embs_batch
#         else:
#             embs_=np.vstack((embs_, embs_batch))

# #np.save('data/mimic/embs_top10_tr.npy', embs_)

# print(embs_.shape)
# np.save('/home/ubuntu/S3/mimic/embs_top10_normal_text_te.npy', embs_)

# %%
top10_icd_codes = train.columns[3:13]
# Out:
# 22238

# %%
def posterior_mode(K, y, return_temporaries=False):
    n = K.shape[0]
    f = tf.zeros(n, dtype=np.float64)
    max_iter_predict = 100
    log_marginal_likelihood = tf.constant(-np.inf, dtype='float64')
    lmls = []
    for i in range(max_iter_predict):

        pi = tf.sigmoid(f)
        W = pi*(1-pi)
        W_sr = tf.sqrt(W)
        W_sr_K = tf.reshape(W_sr, [-1,1])*K
        B = tf.eye(W.shape[0], dtype='float64') + W_sr_K * W_sr
        L = tf.linalg.cholesky(B)
        b = W * f + (y - pi)
        a = b - W_sr * tf.reshape(tf.linalg.cholesky_solve(L, tf.matmul(W_sr_K, tf.reshape(b, (-1,1)))), [-1])
        f = tf.matmul(K, tf.reshape(a, [-1,1]))

        lml = -0.5*tf.matmul(tf.reshape(a, [1,-1]), f)-tf.reduce_sum(tf.math.log(1+tf.math.exp(-(y*2.0-1.0)*tf.reshape(f, [-1]))))- tf.reduce_sum(tf.math.log(tf.linalg.tensor_diag_part(L)))
        f = np.reshape(f, [-1])

        if lml[0,0]-log_marginal_likelihood < 1e-10:
            break
        log_marginal_likelihood = lml
    
    if return_temporaries:
        return f, lml, (pi, W_sr, L, b, a)
    else:
        return f, lml, i

def predict_proba(y, k_w_data_test, k_w_test_test, k_data_test, k_test_test):
    
    #f_mode, Z, (pi_, W_sr_, L_, _, _) = posterior_mode(tf.matmul(x_w_train, x_w_train, transpose_b=True)+k_data_data, return_temporaries=True) 
    f_mode, Z, (pi_, W_sr_, L_, _, _) = posterior_mode(k_w_data_data+k_data_data, y, return_temporaries=True) 
    
    #K_star = tf.matmul(x_w_train, X, transpose_b=True)+k_data_test
    K_star = k_w_data_test+k_data_test
    f_star = tf.matmul(tf.transpose(K_star), tf.reshape(y - pi_, [-1,1]))
    v = tf.linalg.solve(L_, tf.expand_dims(W_sr_, -1) * K_star)
    #var_f_star = tf.linalg.diag_part(tf.matmul(X, X, transpose_b=True)+k_test_test)- tf.reduce_sum(tf.transpose(v)**2, 1)
    var_f_star = tf.linalg.diag_part(k_w_test_test+k_test_test)- tf.reduce_sum(tf.transpose(v)**2, 1)

    LAMBDAS = np.array([0.41, 0.4, 0.37, 0.44, 0.39])[:, np.newaxis]
    COEFS = np.array([-1854.8214151, 3516.89893646, 221.29346712,
                      128.12323805, -2010.49422654])[:, np.newaxis]

    alpha = 1 / (2 * var_f_star)
    gamma = LAMBDAS * tf.reshape(f_star, -1)
    integrals = tf.math.sqrt(tf.constant(math.pi, dtype='float64') / alpha) \
                * tf.math.erf(gamma * tf.math.sqrt(alpha / (alpha + LAMBDAS**2))) \
                / (2 * tf.math.sqrt(var_f_star * 2 * tf.constant(math.pi, dtype='float64')))
    pi_star = tf.reduce_sum(COEFS * integrals, axis=0) + .5 * tf.reduce_sum(COEFS)
    #probs_preds = tf.stack([1 - pi_star, pi_star], axis=1)
    
    return 1 - pi_star, tf.where(tf.greater(f_star, 0), 1, 0)

# %%
from scipy import sparse
from sklearn.metrics import precision_score, recall_score

top10_icd_codes = train.columns[3:13]
#labels_dev = dev[top10_icd_codes]
labels_test = test[top10_icd_codes]
#labels_dev_flat = labels_dev.stack().tolist()
labels_test_flat = labels_test.stack().tolist()
#x_d_dev = X_d_dev
x_d_test = X_d_test
#x_w_dev = sparse.csr_matrix(X_w_dev)
x_w_test = X_w_test_pca


class args(object):
    use_use = True
    project_dir = os.getcwd()
    current_code = 0
    
args = args
config = {'depth': 5, 'nonfn': ['relu'], 'bv': 1.060387, 'wv': 9.927701, 'delta': 0.136233, 'n_resampling': 25}

var_aa_grid = np.load(args.project_dir+'/grid_data/var_aa_grid_{}.npy'.format(config['nonfn'][0]))
corr_ab_grid = np.load(args.project_dir+'/grid_data/corr_ab_grid_{}.npy'.format(config['nonfn'][0]))
qaa_grid = np.load(args.project_dir+'/grid_data/qaa_grid_{}.npy'.format(config['nonfn'][0]))
qab_grid = np.load(args.project_dir+'/grid_data/qab_grid_{}.npy'.format(config['nonfn'][0]))

var_aa_grid = tf.convert_to_tensor(var_aa_grid)
corr_ab_grid = tf.convert_to_tensor(corr_ab_grid)
qaa_grid = tf.convert_to_tensor(qaa_grid)
qab_grid = tf.convert_to_tensor(qab_grid)

## MAKE ONE CONVENIENCE SUBSAMPLE (BALANCED SAMPLE), ADJUST LATER

preds_all_samples = None
preds_probas_all_samples = None
f1s = []
accs = []
for sample in range(config['n_resampling']):

    for col, code in enumerate(top10_icd_codes):
        is_positive = train[code]==1
        N = train.shape[0]
        N_1 = np.sum(is_positive)
        N_0 = N-N_1

        msk0 = np.random.rand(N_0) < config['delta']
        msk1 = np.random.rand(N_1) < config['delta']*int(N_0/N_1)
        
        x_w_train = sparse.csr_matrix(np.concatenate([X_w_train_pca[is_positive][msk1], X_w_train_pca[~is_positive][msk0]], axis=0))
        #x_w_train = np.concatenate([X_w_train_pca[is_positive][msk1], X_w_train_pca[~is_positive][msk0]], axis=0)
        k_w_data_data = config['wv']*x_w_train.dot(x_w_train.T)
        #k_w_data_test = x_w_train.dot(x_w_dev.T)
        k_w_data_test = config['wv']*x_w_train.dot(x_w_test.T)
        #k_w_data_data = k_w_data_data.todense()
        #k_w_data_test = k_w_data_test.todense()

        print("k wide's shape is:", k_w_data_data.shape, k_w_data_test.shape)
        
        x_d_train = np.concatenate([X_d_train[is_positive][msk1], X_d_train[~is_positive][msk0]], axis=0)

        labels_tr = np.concatenate([train[code][is_positive][msk1], 
                                    train[code][~is_positive][msk0]], axis=0)

        print(x_d_train.shape, np.sum(labels_tr))
        
        n_train = x_d_train.shape[0]
        if n_train %4 !=0:
            while n_train % 4 != 0:
                  n_train -= 1
        else:
            pass
        
        x_d_train = x_d_train[:n_train,:]
        k_w_data_data = k_w_data_data[:n_train,:n_train]
        k_w_data_test = k_w_data_test[:n_train,:]
        
        nngp_kernel = nngp2.NNGPKernel(
                depth=config['depth'],
                    weight_var=config['wv'],
                    bias_var=config['bv'],
                    nonlin_fn=config['nonfn'],
                    grid_path=args.project_dir+'/grid_data/',
                    var_aa_grid=var_aa_grid,
                    corr_ab_grid=corr_ab_grid,
                    qaa_grid=qaa_grid,
                    qab_grid=qab_grid,
                    use_fixed_point_norm=False)
        
        k_data_data = nngp_kernel.k_full(input1=tf.constant(x_d_train, dtype='float64'))
        k_data_test = nngp_kernel.k_full(input1=tf.constant(x_d_train, dtype='float64'), input2=tf.constant(x_d_test, dtype='float64'))
        #k_test_test = nngp_kernel.k_full(input1=tf.constant(x_d_dev, dtype='float64'))

        print("k deep's shape is:", k_data_data.shape, k_data_test.shape)


        f_mode, Z, (pi_, W_sr_, L_, _, _) = posterior_mode(k_w_data_data+k_data_data, y=labels_tr, return_temporaries=True) 
        K_star = k_w_data_test+k_data_test
        f_star = tf.matmul(tf.transpose(K_star), tf.reshape(labels_tr - pi_, [-1,1]))
        preds = tf.where(tf.math.greater(f_star, 0), 1, 0)
        #pred_probas, preds = predict_proba(y=labels_tr, k_w_data_test=k_w_data_test, k_w_test_test=k_w_test_test, k_data_test=k_data_test, k_test_test=k_test_test)
        
        print('col {} in sample {} is finished'.format(col, sample))
        
        if col==0:
            persample_preds_all=preds
            #persample_preds_probas = pred_probas[:,0]
        else:
            persample_preds_all=tf.concat([persample_preds_all, preds], axis=1)
            #persample_preds_probas=tf.concat([persample_preds_probas, pred_probas[:,0]], axis=1)

    if preds_all_samples==None:
        preds_all_samples=persample_preds_all
        #preds_probas_all_samples=persample_preds_probas
    else:
        preds_all_samples+=persample_preds_all
        #preds_probas_all_samples+=persample_preds_probas
    
    preds_all_samples_flat = tf.where(tf.greater(tf.reshape(preds_all_samples, -1)/(sample+1), 0.5), 1, 0)
    f1 = f1_score(labels_test_flat, preds_all_samples_flat)
    acc = np.mean(labels_test_flat == preds_all_samples_flat)
    ps = precision_score(labels_test_flat, preds_all_samples_flat)
    rs = recall_score(labels_test_flat, preds_all_samples_flat)
    print('{} Samples'.format(sample), f1, acc, ps, rs)
    f1s.append(f1)
    accs.append(acc)
    
# preds_final = tf.ec2(tf.math.greater(preds_all_samples/config['n_resampling'], 0.5), 1, 0)
# f1_final = f1_score(labels_dev_flat, np.reshape(preds_final, -1))
# acc_final = np.mean(labels_dev_flat == np.reshape(preds_final, -1))

# %%
int(N_0/N_1)
# Out:
# 5

# %%
class args(object):
    use_use = True
    project_dir = os.getcwd()
    current_code = 0
    
args = args
config = {'depth': 7, 'nonfn': ['relu'], 'bv': 2.6196, 'wv': 2.1159, 'delta': 0.17366, 'n_resampling': 9}
top10_icd_codes = train.columns[3:13]
is_positive = train[top10_icd_codes[0]]==1
N = train.shape[0]
N_1 = np.sum(is_positive)
N_0 = N-N_1

msk0 = np.random.rand(N_0) < config['delta']
msk1 = np.random.rand(N_1) < config['delta']*(int(N_0/N_1))

x_d_train = np.concatenate([X_d_train[is_positive][msk1], X_d_train[~is_positive][msk0]], axis=0)
x_d_dev = X_d_dev

# %%
# np.save('/home/ubuntu/S3/mimic/X_w_train_pca.npy', X_w_train_pca)
#np.save('/home/ubuntu/S3/mimic/X_w_dev_pca.npy', x_w_dev_pca)

# %%
# COMPUTE DEEP KERNEL 
config = {'depth': 1, 'nonfn': ['relu'], 'bv': 1.060387, 'wv': 9.927701}

var_aa_grid = np.load(args.project_dir+'/grid_data/var_aa_grid_{}.npy'.format(config['nonfn'][0]))
corr_ab_grid = np.load(args.project_dir+'/grid_data/corr_ab_grid_{}.npy'.format(config['nonfn'][0]))
qaa_grid = np.load(args.project_dir+'/grid_data/qaa_grid_{}.npy'.format(config['nonfn'][0]))
qab_grid = np.load(args.project_dir+'/grid_data/qab_grid_{}.npy'.format(config['nonfn'][0]))

var_aa_grid = tf.convert_to_tensor(var_aa_grid)
corr_ab_grid = tf.convert_to_tensor(corr_ab_grid)
qaa_grid = tf.convert_to_tensor(qaa_grid)
qab_grid = tf.convert_to_tensor(qab_grid)

nngp_kernel = nngp2.NNGPKernel(
    depth=config['depth'],
        weight_var=config['wv'],
        bias_var=config['bv'],
        nonlin_fn=config['nonfn'],
        grid_path=args.project_dir+'/grid_data/',
        var_aa_grid=var_aa_grid,
        corr_ab_grid=corr_ab_grid,
        qaa_grid=qaa_grid,
        qab_grid=qab_grid,
        use_fixed_point_norm=False)

k_data_data = nngp_kernel.k_full(input1=tf.constant(x_d_train, dtype='float64'))
# k_data_test = nngp_kernel.k_full(input1=tf.constant(x_d_train, dtype='float64'), input2=tf.constant(x_d_dev, dtype='float64'))
# k_test_test = nngp_kernel.k_full(input1=tf.constant(x_d_dev, dtype='float64'))

#print("k's shape is:", k_data_data.shape, k_data_test.shape, k_test_test.shape)
# Out:
# 302 1
# computing kernel for batch:0

# %%
k_data_data
# Out:
# <tf.Tensor: shape=(100, 100), dtype=float64, numpy=
# array([[54.26833911, 51.79509794, 52.37325461, ..., 51.03691037,
#         45.55731979, 48.94765087],
#        [51.79509794, 54.26833911, 51.86128872, ..., 51.17349011,
#         45.86920939, 49.16292696],
#        [52.37325461, 51.86128872, 54.26833911, ..., 51.29464985,
#         43.99654372, 49.43578984],
#        ...,
#        [51.03691037, 51.17349011, 51.29464985, ..., 54.26833911,
#         46.42294866, 50.97111433],
#        [45.55731979, 45.86920939, 43.99654372, ..., 46.42294866,
#         54.26833911, 47.00001003],
#        [48.94765087, 49.16292696, 49.43578984, ..., 50.97111433,
#         47.00001003, 54.26833911]])>

# %%
input1 = tf.convert_to_tensor(X_d_train[:100, :])

input1 = nngp_kernel._input_layer_normalization(input1)
input2 = input1

cov_init = tf.matmul(input1, input2, transpose_b=True) / input1.shape[1] #100,100; den is a tensor

nngp_kernel.k_diag(input1, input_wx=None) #110 vars
q_aa_init = nngp_kernel.layer_qaa_dict[0] #L个

q_ab = cov_init
q_ab = nngp_kernel.weight_var * q_ab + nngp_kernel.bias_var #100, 100
#corr = q_ab / q_aa_init[0]
corr = tf.cast(q_ab, tf.float32) / tf.cast(q_aa_init[0], tf.float32) #100, 100

batch_size, batch_count = nngp_kernel._get_batch_size_and_count(input1, input2)

q_ab_all = []
b_x = 0

corr_flat_batch = corr[batch_size * b_x : batch_size * (b_x + 1), :]#batchsize, 100
corr_flat_batch = tf.reshape(corr_flat_batch, [-1]) #batchsize*100
#w_cov_flat_batch = tf.reshape(w_cov[batch_size * b_x : batch_size * (b_x + 1), :], [-1])
l=0
q_aa = nngp_kernel.layer_qaa_dict[l]

# q_ab = interp2.interp_lin_2d(x=nngp_kernel.var_aa_grid,
#                           y=nngp_kernel.corr_ab_grid,
#                           z=nngp_kernel.qab_grid,
#                           xp=q_aa,
#                           yp=tf.cast(corr_flat_batch, tf.float64)) #10000

x=nngp_kernel.var_aa_grid
y=nngp_kernel.corr_ab_grid
z=nngp_kernel.qab_grid
xp=q_aa
yp=tf.cast(corr_flat_batch, tf.float64)

# #xp, tf.shape(yp)[0]
xp = tf.tile(xp, yp.shape)
xyp = tf.expand_dims(tf.stack([xp, yp]), 1) #shape=(2, 1, 632025)
xy0 = tf.reshape(tf.stack([x[0], y[0]]), [2, 1, 1])
xy1 = tf.reshape(tf.stack([x[1], y[1]]), [2, 1, 1])

spacing = xy1 - xy0
ind_grid = (xyp - xy0) / spacing #shape=(2, 1, 632025)
ind = tf.cast(ind_grid, tf.int32) + [[[0], [1]]] #shape=(2, 2, 632025)

max_ind = [[[x.shape[0] - 1]], [[y.shape[0] - 1]]]
ind = tf.minimum(ind, max_ind) #(2, 2, 632025)
ind_float = tf.cast(ind, tf.float64)

xy_grid = ind_float * spacing + xy0

weight = tf.abs(xyp - xy_grid) / spacing

weight = 1. - weight

weight_sum = tf.reduce_sum(weight, axis=1, keepdims=True)
weight /= weight_sum #(2, 2, 632025)

zp_accum = 0.

for ind_x, weight_x in [(ind[0, 0], weight[0, 0]), #ind_x: (x1, x2), ind_y: (y1, y2)
                        (ind[0, 1], weight[0, 1])]:
    for ind_y, weight_y in [(ind[1, 0], weight[1, 0]),
                          (ind[1, 1], weight[1, 1])]:
        zp = tf.gather_nd(z, tf.stack([ind_x, ind_y], axis=1)) #stack along dim1: (x1, y1), (x2, y2)
        zp_accum += zp * weight_x * weight_y #(z1, z2)*10000-> ()

# %%
zp_accum
# Out:
# <tf.Tensor: shape=(10000,), dtype=float64, numpy=
# array([5.35954418, 5.11041767, 5.16865466, ..., 5.02741926, 4.62741942,
#        5.35954418])>

# %%
q_aa
# Out:
# <tf.Tensor: shape=(1,), dtype=float64, numpy=array([10.988088])>

# %%
from tensorflow_probability.python.internal import assert_util
from tensorflow_probability.python.internal import tensor_util
from tensorflow_probability.python.math.psd_kernels.internal import util
from tensorflow_probability.python.math.psd_kernels.positive_semidefinite_kernel import PositiveSemidefiniteKernel

constrain_positive = tfb.Shift(np.finfo(np.float64).tiny)(tfb.Softplus())

amplitude = tfp.util.TransformedVariable(
    initial_value=1.,
    bijector=constrain_positive,
    name='amplitude',
    dtype=np.float64)

length_scale = tfp.util.TransformedVariable(
    initial_value=np.array([1.0]*10),
    bijector=constrain_positive,
    name='length_scale',
    dtype=np.float64)

class ExponentiatedQuadraticScale(PositiveSemidefiniteKernel):


  def __init__(self,
               amplitude=None,
               length_scale=None,
               feature_ndims=1,
               validate_args=False,
               name='ExponentiatedQuadraticScale'):

    parameters = dict(locals())
    with tf.name_scope(name):
      dtype = util.maybe_get_common_dtype(
          [amplitude, length_scale])
      self._amplitude = tensor_util.convert_nonref_to_tensor(
          amplitude, name='amplitude', dtype=dtype)
      self._length_scale = tensor_util.convert_nonref_to_tensor(
          length_scale, name='length_scale', dtype=dtype)
      super(ExponentiatedQuadraticScale, self).__init__(
          feature_ndims,
          dtype=dtype,
          name=name,
          validate_args=validate_args,
          parameters=parameters)

  @property
  def amplitude(self):
    """Amplitude parameter."""
    return self._amplitude

  @property
  def length_scale(self):
    """Length scale parameter."""
    return self._length_scale

  def _batch_shape(self):
    scalar_shape = tf.TensorShape([])
    return tf.broadcast_static_shape(
        scalar_shape if self.amplitude is None else self.amplitude.shape,
        scalar_shape if self.length_scale is None else self.length_scale.shape)

  def _batch_shape_tensor(self):
    return tf.broadcast_dynamic_shape(
        [] if self.amplitude is None else tf.shape(self.amplitude),
        [] if self.length_scale is None else tf.shape(self.length_scale))

  def _apply_with_distance(
      self, x1, x2, pairwise_square_distance, example_ndims=0):
    exponent = -0.5 * pairwise_square_distance
    if self.length_scale is not None:
      length_scale = tf.convert_to_tensor(self.length_scale)
      length_scale = util.pad_shape_with_ones(
          length_scale, example_ndims)
      exponent = exponent #/ length_scale**2

    if self.amplitude is not None:
      amplitude = tf.convert_to_tensor(self.amplitude)
      amplitude = util.pad_shape_with_ones(amplitude, example_ndims)
      exponent = exponent + tf.math.log(amplitude**2.)

    return tf.exp(exponent)

  def _apply(self, x1, x2, example_ndims=0):
    x1 = x1/self.length_scale
    x2 = x2/self.length_scale
    pairwise_square_distance = util.sum_rightmost_ndims_preserving_shape(
        tf.math.squared_difference(x1, x2), self.feature_ndims)
    return self._apply_with_distance(
        x1, x2, pairwise_square_distance, example_ndims=example_ndims)

  def _matrix(self, x1, x2):
    
    x1 = x1/self.length_scale
    x2 = x2/self.length_scale
    pairwise_square_distance = util.pairwise_square_distance_matrix(
        x1, x2, self.feature_ndims)
    return self._apply_with_distance(
        x1, x2, pairwise_square_distance, example_ndims=2)

  def _tensor(self, x1, x2, x1_example_ndims, x2_example_ndims):
    x1 = x1/self.length_scale
    x2 = x2/self.length_scale
    pairwise_square_distance = util.pairwise_square_distance_tensor(
        x1, x2, self.feature_ndims, x1_example_ndims, x2_example_ndims)
    return self._apply_with_distance(
        x1, x2, pairwise_square_distance,
        example_ndims=(x1_example_ndims + x2_example_ndims))

  def _parameter_control_dependencies(self, is_init):
    if not self.validate_args:
      return []
    assertions = []
    for arg_name, arg in dict(amplitude=self.amplitude,
                              length_scale=self.length_scale).items():
      if arg is not None and is_init != tensor_util.is_ref(arg):
        assertions.append(assert_util.assert_positive(
            arg,
            message='{} must be positive.'.format(arg_name)))
    return assertions

# %%
# np.save('k_data_data.npy', k_data_data)
# np.save('k_data_test.npy', k_data_test)
# np.save('x_w_train.npy', x_w_train)
# np.save('x_w_dev.npy', x_w_dev)
# np.save('y.npy', y)
#np.save('k_test_test.npy', k_test_test)

# %%
## TEST BY PART

y = labels_tr

def posterior_mode(K, return_temporaries=False):
    n = K.shape[0]
    f = tf.zeros(n, dtype=np.float64)
    max_iter_predict = 100
    log_marginal_likelihood = tf.constant(-np.inf, dtype='float64')
    lmls = []
    for i in range(max_iter_predict):

        pi = tf.sigmoid(f)
        W = pi*(1-pi)
        W_sr = tf.sqrt(W)
        W_sr_K = tf.reshape(W_sr, [-1,1])*K
        B = tf.eye(W.shape[0], dtype='float64') + W_sr_K * W_sr
        L = tf.linalg.cholesky(B)
        b = W * f + (y - pi)
        a = b - W_sr * tf.reshape(tf.linalg.cholesky_solve(L, tf.matmul(W_sr_K, tf.reshape(b, (-1,1)))), [-1])
        f = tf.matmul(K, tf.reshape(a, [-1,1]))

        lml = -0.5*tf.matmul(tf.reshape(a, [1,-1]), f)-tf.reduce_sum(tf.math.log(1+tf.math.exp(-(y*2.0-1.0)*tf.reshape(f, [-1]))))- tf.reduce_sum(tf.math.log(tf.linalg.tensor_diag_part(L)))
        f = np.reshape(f, [-1])

        if lml[0,0]-log_marginal_likelihood < 1e-10:
            break
        log_marginal_likelihood = lml
    
    if return_temporaries:
        return f, lml, (pi, W_sr, L, b, a)
    else:
        return f, lml, i

def predict_proba(X, k_w_data_test, k_w_test_test, k_data_test, k_test_test):
    
    #f_mode, Z, (pi_, W_sr_, L_, _, _) = posterior_mode(tf.matmul(x_w_train, x_w_train, transpose_b=True)+k_data_data, return_temporaries=True) 
    f_mode, Z, (pi_, W_sr_, L_, _, _) = posterior_mode(k_w_data_data+k_data_data, return_temporaries=True) 
    
    #K_star = tf.matmul(x_w_train, X, transpose_b=True)+k_data_test
    K_star = k_w_data_test+k_data_test
    f_star = tf.matmul(tf.transpose(K_star), tf.reshape(y - pi_, [-1,1]))
    v = tf.linalg.solve(L_, tf.expand_dims(W_sr_, -1) * K_star)
    #var_f_star = tf.linalg.diag_part(tf.matmul(X, X, transpose_b=True)+k_test_test)- tf.reduce_sum(tf.transpose(v)**2, 1)
    var_f_star = tf.linalg.diag_part(k_w_test_test+k_test_test)- tf.reduce_sum(tf.transpose(v)**2, 1)

    LAMBDAS = np.array([0.41, 0.4, 0.37, 0.44, 0.39])[:, np.newaxis]
    COEFS = np.array([-1854.8214151, 3516.89893646, 221.29346712,
                      128.12323805, -2010.49422654])[:, np.newaxis]

    alpha = 1 / (2 * var_f_star)
    gamma = LAMBDAS * tf.reshape(f_star, -1)
    integrals = tf.math.sqrt(tf.constant(math.pi, dtype='float64') / alpha) \
                * tf.math.erf(gamma * tf.math.sqrt(alpha / (alpha + LAMBDAS**2))) \
                / (2 * tf.math.sqrt(var_f_star * 2 * tf.constant(math.pi, dtype='float64')))
    pi_star = tf.reduce_sum(COEFS * integrals, axis=0) + .5 * tf.reduce_sum(COEFS)
    probs_preds = tf.stack([1 - pi_star, pi_star], axis=1)
    
    return probs_preds, np.where(f_star > 0, 1, 0)

#f_mode, lmls, i = posterior_mode(K[0], return_temporaries=True)

# start = np.array([0.]*11, dtype='float64')
# def log_marginal_likelihood(params):
#     print(params)
#     amplitude = tf.math.exp(params[0])
#     length_scale = tf.math.exp(params[1:])

#     kernel = ExponentiatedQuadraticScale(amplitude, length_scale)
#     K = kernel.matrix(tf.constant(x_w_train, dtype='float64'), tf.constant(x_w_train, dtype='float64'))
    
#     f_mode, Z, _ = posterior_mode(K, return_temporaries=False)
#     print(f_mode, Z)
#     return Z[0,0]

# def make_val_and_grad_fn(params):
#     val_and_grad = tfp.math.value_and_gradient(log_marginal_likelihood, params)
#     val_and_grad = (-val_and_grad[0], -val_and_grad[1])

#     return val_and_grad

# optim_results = tfp.optimizer.lbfgs_minimize(
#       make_val_and_grad_fn,
#       initial_position=start,
#       f_relative_tolerance=0.00001)

# amplitude = tf.math.exp(optim_results.position[0])
# length_scale = tf.math.exp(optim_results.position[1:])

# kernel = ExponentiatedQuadraticScale(amplitude, length_scale)
# K = kernel.matrix(tf.constant(x_w_train, dtype='float64'), tf.constant(x_w_train, dtype='float64'))+k_data_data
# f_mode, Z, (pi_, W_sr_, L_, _, _) = posterior_mode(K, return_temporaries=True) 

# K_star = kernel.matrix(tf.constant(x_w_train, dtype='float64'), tf.constant(x_w_dev, dtype='float64'))+k_data_test
# f_star = tf.matmul(tf.transpose(K_star), tf.reshape(y - pi_, [-1,1]))
# f_star_flat = tf.reshape(f_star, [-1])
# label_preds = tf.where(tf.math.greater(f_star_flat, 0), 1, 0)

# from sklearn.metrics import f1_score
# f1 = f1_score(labels_dev, label_preds.numpy())
# acc = np.mean(labels_dev == label_preds.numpy())
# print(f1, acc, labels_dev.value_counts())

# %%
y = labels_tr

f_mode, Z, (pi_, W_sr_, L_, _, _) = posterior_mode(k_w_data_data+k_data_data, return_temporaries=True) 
K_star = k_w_data_test+k_data_test
f_star = tf.matmul(tf.transpose(K_star), tf.reshape(y - pi_, [-1,1]))
f_star_flat = tf.reshape(f_star, [-1])
preds = tf.where(tf.math.greater(f_star_flat, 0), 1, 0)


from sklearn.metrics import f1_score
f1 = f1_score(labels_dev, np.reshape(preds, -1))
acc = np.mean(labels_dev == np.reshape(preds, -1))
print(f1, acc, labels_dev.value_counts())
# Out:
# 0.44283559577677223 0.7694132334581772 0    6831
# 1    1179
# Name: 53081, dtype: int64

# %%
from sklearn.metrics import confusion_matrix

#pred_probs_tr, preds_tr = predict_proba(X=x_w_train, k_data_test=k_data_data, k_test_test=k_data_data)
pred_probs, preds = predict_proba(X=x_w_dev, k_w_data_test=k_w_data_test, k_w_test_test=k_w_test_test, k_data_test=k_data_test, k_test_test=k_test_test)

pred_probs_tr, preds_tr = predict_proba(X=x_w_dev, k_w_data_test=k_w_data_data, k_w_test_test=k_w_data_data, k_data_test=k_data_data, k_test_test=k_data_data)

cm = confusion_matrix(np.reshape(preds, -1), labels_dev)
cm_tr = confusion_matrix(np.reshape(preds_tr, -1), labels_tr)

p0 = (cm[1,0]+cm[0,0])/cm.sum()
p1 = (cm[0,1]+cm[1,1])/cm.sum()
pt01 = cm_tr[0, 1]/(cm_tr[0,1]+cm_tr[1,1])
pt00 = cm_tr[0, 0]/(cm_tr[0,1]+cm_tr[1,1])
pt10 = cm_tr[1, 0]/(cm_tr[1,0]+cm_tr[0,0])
pt11 = cm_tr[1, 1]/(cm_tr[1,0]+cm_tr[0,0])
A = np.array([[pt00, pt01], [pt10, pt11]])
b = np.array([[p0], [p1]])
pw = solve(A, b)
pw0 = pw[0,0]
pw1 = pw[1,0]

# %%
num0 = pw0*pred_probs[:,0]/np.mean(preds_tr==0)
den = pw0*pred_probs[:,0]/np.mean(preds_tr==0)+pw1*pred_probs[:,1]/np.mean(preds_tr==1)
f1_score(tf.where(tf.math.greater(num0/den, 0.5), 0, 1), labels_dev), f1_score(preds, labels_dev)
np.mean(tf.where(tf.math.greater(num0/den, 0.5), 0, 1)== labels_dev), np.mean(np.reshape(preds, -1)==labels_dev)
# Out:
# (0.83458177278402, 0.7426966292134831)

# %%
KK = tf.matmul(x_w_train, x_w_train, transpose_b=True)+k_data_data

import seaborn as sns

ax = sns.heatmap(KK[0:200, 0:200])

# %%
y_ = np.reshape((y).tolist(), [-1,1])[0:200, :]
ax = sns.heatmap(tf.matmul(y_, y_, transpose_b=True))

# %%
### RUN AS A WHOLE 

import time
from sklearn.metrics import f1_score
from classifiers import TFBinaryGPClassifier

kernel = ExponentiatedQuadraticScale(tf.constant(1.0, dtype='float64'), tf.constant([1.0]*10, dtype='float64'))

start = time.time()

BGPC = TFBinaryGPClassifier(kernel=kernel).fit(X=x_w_train, y=labels_tr, k_data_data=k_data_data)
labels_preds = BGPC.predict(X=x_w_dev, k_data_test=k_data_test)
end =time.time()

f1 = f1_score(labels_dev, labels_preds.numpy())
acc = np.mean(labels_dev == labels_preds.numpy())
print(f1, acc, end-start)
# Out:
# 0.47693480747235995 0.31485642946317105 21.0160973072052

# %%
tf.matmul(x_w_train, x_w_train, transpose_b=True)+k_data_data
# Out:
# <tf.Tensor: shape=(2801, 2801), dtype=float64, numpy=
# array([[ 3.33148929,  2.18303275,  1.37611304, ...,  2.27051268,
#          1.64892318,  2.1008498 ],
#        [ 2.18303275,  2.41916461,  1.98938396, ...,  1.24429239,
#          2.25910585,  2.36060241],
#        [ 1.37611304,  1.98938396,  3.76323601, ...,  0.17427336,
#          2.62133009,  2.09141087],
#        ...,
#        [ 2.27051268,  1.24429239,  0.17427336, ..., 20.72136743,
#          0.45353822,  1.11797064],
#        [ 1.64892318,  2.25910585,  2.62133009, ...,  0.45353822,
#          2.90806868,  2.35579495],
#        [ 2.1008498 ,  2.36060241,  2.09141087, ...,  1.11797064,
#          2.35579495,  2.40320324]])>

# %%
from sklearn.gaussian_process._gpc import _BinaryGaussianProcessClassifierLaplace

gpc = _BinaryGaussianProcessClassifierLaplace().fit(X=x_w_train, y=labels_tr)
preds = gpc.predict_proba(X=x_w_dev)
